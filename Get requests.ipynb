# %%
import requests

# %%
import json

# %%
page = requests.get("https://api.datamuse.com/words?rel_rhy=funny")

# %%
print(type(page))
# Out:
# <class 'requests.models.Response'>

# %%
print(page.text[:150]) # print the first 150 characters
# Out:
# [{"word":"money","score":4415,"numSyllables":2},{"word":"honey","score":1206,"numSyllables":2},{"word":"sunny","score":717,"numSyllables":2},{"word":"

# %%
print(page.url) # print the url that was fetched
# Out:
# https://api.datamuse.com/words?rel_rhy=funny

# %%
print("------")
# Out:
# ------

# %% [markdown]
# # Convert the Response class object into a list

# %%
x = page.json() # turn page.text into a python object

# %%
print(type(x))
# Out:
# <class 'list'>

# %%
print("---first item in the list---")
print(x[0])
# Out:
# ---first item in the list---
# {'word': 'money', 'score': 4415, 'numSyllables': 2}

# %%
print("---the whole list, pretty printed---")
print(json.dumps(x, indent=2)) # pretty print the results
# Out:
# ---the whole list, pretty printed---
# [
#   {
#     "word": "money",
#     "score": 4415,
#     "numSyllables": 2
#   },
#   {
#     "word": "honey",
#     "score": 1206,
#     "numSyllables": 2
#   },
#   {
#     "word": "sunny",
#     "score": 717,
#     "numSyllables": 2
#   },
#   {
#     "word": "bunny",
#     "score": 702,
#     "numSyllables": 2
#   },
#   {
#     "word": "blini",
#     "score": 613,
#     "numSyllables": 2
#   },
#   {
#     "word": "gunny",
#     "score": 449,
#     "numSyllables": 2
#   },
#   {
#     "word": "tunny",
#     "score": 301,
#     "numSyllables": 2
#   },
#   {
#     "word": "sonny",
#     "score": 286,
#     "numSyllables": 2
#   },
#   {
#     "word": "dunny",
#     "score": 245,
#     "numSyllables": 2
#   },
#   {
#     "word": "runny",
#     "score": 225,
#     "numSyllables": 2
#   },
#   {
#     "word": "thunny",
#     "score": 222,
#     "numSyllables": 2
#   },
#   {
#     "word": "aknee",
#     "score": 179,
#     "numSyllables": 2
#   },
#   {
#     "word": "squinny",
#     "score": 170,
#     "numSyllables": 2
#   },
#   {
#     "word": "fiat money",
#     "score": 160,
#     "numSyllables": 4
#   },
#   {
#     "word": "gunnie",
#     "score": 156,
#     "numSyllables": 2
#   },
#   {
#     "word": "blood money",
#     "score": 152,
#     "numSyllables": 3
#   },
#   {
#     "word": "squiny",
#     "score": 151,
#     "numSyllables": 2
#   },
#   {
#     "word": "tunney",
#     "score": 119,
#     "numSyllables": 2
#   },
#   {
#     "word": "spinny",
#     "score": 117,
#     "numSyllables": 2
#   },
#   {
#     "word": "pin money",
#     "score": 107,
#     "numSyllables": 3
#   },
#   {
#     "word": "easy money",
#     "score": 66,
#     "numSyllables": 4
#   },
#   {
#     "word": "smart money",
#     "score": 66,
#     "numSyllables": 3
#   },
#   {
#     "word": "earnest money",
#     "score": 62,
#     "numSyllables": 4
#   },
#   {
#     "word": "easter bunny",
#     "score": 56,
#     "numSyllables": 4
#   },
#   {
#     "word": "paper money",
#     "score": 54,
#     "numSyllables": 4
#   },
#   {
#     "word": "pocket money",
#     "score": 47,
#     "numSyllables": 4
#   },
#   {
#     "word": "folding money",
#     "score": 46,
#     "numSyllables": 4
#   },
#   {
#     "word": "conscience money",
#     "score": 41,
#     "numSyllables": 4
#   },
#   {
#     "word": "hush money",
#     "score": 40,
#     "numSyllables": 3
#   },
#   {
#     "word": "prize money",
#     "score": 37,
#     "numSyllables": 3
#   },
#   {
#     "word": "amount of money",
#     "score": 33,
#     "numSyllables": 5
#   },
#   {
#     "word": "for love or money",
#     "score": 32,
#     "numSyllables": 5
#   },
#   {
#     "word": "tight money",
#     "score": 32,
#     "numSyllables": 3
#   },
#   {
#     "word": "ship money",
#     "score": 30,
#     "numSyllables": 3
#   },
#   {
#     "word": "metal money",
#     "score": 27,
#     "numSyllables": 4
#   },
#   {
#     "word": "sum of money",
#     "score": 23,
#     "numSyllables": 4
#   },
#   {
#     "word": "entrance money",
#     "score": 22,
#     "numSyllables": 4
#   },
#   {
#     "word": "cheap money",
#     "score": 21,
#     "numSyllables": 3
#   },
#   {
#     "word": "spending money",
#     "score": 21,
#     "numSyllables": 4
#   },
#   {
#     "word": "token money",
#     "score": 21,
#     "numSyllables": 4
#   },
#   {
#     "word": "waste of money",
#     "score": 19,
#     "numSyllables": 4
#   },
#   {
#     "word": "ransom money",
#     "score": 18,
#     "numSyllables": 4
#   },
#   {
#     "word": "hearth money",
#     "score": 14,
#     "numSyllables": 3
#   },
#   {
#     "word": "munni",
#     "score": 14,
#     "numSyllables": 2
#   },
#   {
#     "word": "bunnie",
#     "score": 2,
#     "numSyllables": 2
#   },
#   {
#     "word": "euromoney",
#     "score": 2,
#     "numSyllables": 4
#   },
#   {
#     "word": "smartmoney",
#     "score": 2,
#     "numSyllables": 3
#   },
#   {
#     "word": "anyone he",
#     "numSyllables": 4
#   },
#   {
#     "word": "begun he",
#     "numSyllables": 3
#   },
#   {
#     "word": "bunney",
#     "numSyllables": 2
#   },
#   {
#     "word": "ca ne",
#     "numSyllables": 2
#   },
#   {
#     "word": "done he",
#     "numSyllables": 2
#   },
#   {
#     "word": "donne e",
#     "numSyllables": 2
#   },
#   {
#     "word": "everyone he",
#     "numSyllables": 4
#   },
#   {
#     "word": "fun he",
#     "numSyllables": 2
#   },
#   {
#     "word": "grandson he",
#     "numSyllables": 3
#   },
#   {
#     "word": "gun he",
#     "numSyllables": 2
#   },
#   {
#     "word": "handgun he",
#     "numSyllables": 3
#   },
#   {
#     "word": "kun hee",
#     "numSyllables": 2
#   },
#   {
#     "word": "le ne",
#     "numSyllables": 2
#   },
#   {
#     "word": "lunney",
#     "numSyllables": 2
#   },
#   {
#     "word": "lunny",
#     "numSyllables": 2
#   },
#   {
#     "word": "none e",
#     "numSyllables": 2
#   },
#   {
#     "word": "none he",
#     "numSyllables": 2
#   },
#   {
#     "word": "nun he",
#     "numSyllables": 2
#   },
#   {
#     "word": "one he",
#     "numSyllables": 2
#   },
#   {
#     "word": "one knee",
#     "numSyllables": 2
#   },
#   {
#     "word": "pun he",
#     "numSyllables": 2
#   },
#   {
#     "word": "run e",
#     "numSyllables": 2
#   },
#   {
#     "word": "run he",
#     "numSyllables": 2
#   },
#   {
#     "word": "shotgun he",
#     "numSyllables": 3
#   },
#   {
#     "word": "someone e",
#     "numSyllables": 3
#   },
#   {
#     "word": "someone he",
#     "numSyllables": 3
#   },
#   {
#     "word": "son e",
#     "numSyllables": 2
#   },
#   {
#     "word": "son he",
#     "numSyllables": 2
#   },
#   {
#     "word": "sun e",
#     "numSyllables": 2
#   },
#   {
#     "word": "sun he",
#     "numSyllables": 2
#   },
#   {
#     "word": "ton he",
#     "numSyllables": 2
#   },
#   {
#     "word": "ton ne",
#     "numSyllables": 2
#   },
#   {
#     "word": "un e",
#     "numSyllables": 2
#   },
#   {
#     "word": "un he",
#     "numSyllables": 2
#   },
#   {
#     "word": "un ne",
#     "numSyllables": 2
#   },
#   {
#     "word": "un ni",
#     "numSyllables": 2
#   },
#   {
#     "word": "won he",
#     "numSyllables": 2
#   }
# ]

# %%
page = requests.get("https://api.datamuse.com/words?rel_rhy=turtle")

# %%
print(page.text[:150]) # print the first 150 characters
# Out:
# [{"word":"myrtle","score":866,"numSyllables":2},{"word":"fertile","score":813,"numSyllables":2},{"word":"hurtle","score":667,"numSyllables":2},{"word"

# %%
x = page.json() # turn page.text into a python object

# %%
print("---the whole list, pretty printed---")
print(json.dumps(x, indent=2)) # pretty print the results
# Out:
# ---the whole list, pretty printed---
# [
#   {
#     "word": "myrtle",
#     "score": 866,
#     "numSyllables": 2
#   },
#   {
#     "word": "fertile",
#     "score": 813,
#     "numSyllables": 2
#   },
#   {
#     "word": "hurtle",
#     "score": 667,
#     "numSyllables": 2
#   },
#   {
#     "word": "infertile",
#     "score": 214,
#     "numSyllables": 3
#   },
#   {
#     "word": "curtal",
#     "score": 176,
#     "numSyllables": 2
#   },
#   {
#     "word": "crepe myrtle",
#     "score": 57,
#     "numSyllables": 3
#   },
#   {
#     "word": "wax myrtle",
#     "score": 40,
#     "numSyllables": 3
#   },
#   {
#     "word": "hertel",
#     "score": 35,
#     "numSyllables": 2
#   },
#   {
#     "word": "bay myrtle",
#     "score": 32,
#     "numSyllables": 3
#   },
#   {
#     "word": "sand myrtle",
#     "score": 27,
#     "numSyllables": 3
#   },
#   {
#     "word": "bog myrtle",
#     "score": 25,
#     "numSyllables": 3
#   },
#   {
#     "word": "oregon myrtle",
#     "score": 22,
#     "numSyllables": 5
#   },
#   {
#     "word": "ertl",
#     "score": 19,
#     "numSyllables": 2
#   },
#   {
#     "word": "ertel",
#     "score": 14,
#     "numSyllables": 2
#   },
#   {
#     "word": "common myrtle",
#     "score": 13,
#     "numSyllables": 4
#   },
#   {
#     "word": "pirtle",
#     "score": 10,
#     "numSyllables": 2
#   },
#   {
#     "word": "purtell",
#     "score": 8,
#     "numSyllables": 2
#   },
#   {
#     "word": "bertil",
#     "score": 7,
#     "numSyllables": 2
#   },
#   {
#     "word": "ertle",
#     "score": 3,
#     "numSyllables": 2
#   },
#   {
#     "word": "avert ill",
#     "numSyllables": 3
#   },
#   {
#     "word": "birtle",
#     "numSyllables": 2
#   },
#   {
#     "word": "burt hill",
#     "numSyllables": 2
#   },
#   {
#     "word": "defer till",
#     "numSyllables": 3
#   },
#   {
#     "word": "dirt hill",
#     "numSyllables": 2
#   },
#   {
#     "word": "er til",
#     "numSyllables": 2
#   },
#   {
#     "word": "her till",
#     "numSyllables": 2
#   },
#   {
#     "word": "hirtle",
#     "numSyllables": 2
#   },
#   {
#     "word": "hurt till",
#     "numSyllables": 2
#   },
#   {
#     "word": "mertle",
#     "numSyllables": 2
#   },
#   {
#     "word": "mirtle",
#     "numSyllables": 2
#   },
#   {
#     "word": "occur till",
#     "numSyllables": 3
#   },
#   {
#     "word": "purtle",
#     "numSyllables": 2
#   },
#   {
#     "word": "shirt till",
#     "numSyllables": 2
#   },
#   {
#     "word": "stir till",
#     "numSyllables": 2
#   }
# ]

# %%
# page = requests.get("https://api.datamuse.com/words?rel_rhy=crunchy")

# %%
kval_pairs = {'rel_rhy': 'crunchy'}

# %%
page = requests.get("https://api.datamuse.com/words", params=kval_pairs)

# %%
print(page.text[:150]) # print the first 150 characters
# Out:
# [{"word":"punchy","score":531,"numSyllables":2},{"word":"scrunchy","score":166,"numSyllables":2},{"word":"bunchy","score":155,"numSyllables":2},{"word

# %%
print(page.url) # print the url that was fetched
# Out:
# https://api.datamuse.com/words?rel_rhy=crunchy
